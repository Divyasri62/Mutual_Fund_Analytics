# %%
import pandas as pd

# %%
fund = pd.read_csv("c:/Users/Divya/Downloads/MutualFundAnalytics_Project_1/data/raw/fund_master.csv")

# %%
fund.head()
# Out:
#    Scheme_Code                                 Scheme_Name  \
# 0       100033  Aditya Birla Sun Life Large & Mid Cap Fund
# 1       100034  Aditya Birla Sun Life Large & Mid Cap Fund
# 2       100037           Aditya Birla Sun Life Income Fund
# 3       100038           Aditya Birla Sun Life Income Fund
# 4       100039           Aditya Birla Sun Life Income Fund
#
#                                  AMC Scheme_Type  \
# 0  Aditya Birla Sun Life AMC Limited  Open Ended
# 1  Aditya Birla Sun Life AMC Limited  Open Ended
# 2  Aditya Birla Sun Life AMC Limited  Open Ended
# 3  Aditya Birla Sun Life AMC Limited  Open Ended
# 4  Aditya Birla Sun Life AMC Limited  Open Ended
#
#                               Scheme_Category  \
# 0        Equity Scheme - Large & Mid Cap Fund
# 1        Equity Scheme - Large & Mid Cap Fund
# 2  Debt Scheme - Medium to Long Duration Fund
# 3  Debt Scheme - Medium to Long Duration Fund
# 4  Debt Scheme - Medium to Long Duration Fund
#
# ...

# %%
fund.columns
# Out:
# Index(['Scheme_Code', 'Scheme_Name', 'AMC', 'Scheme_Type', 'Scheme_Category',
#        'Scheme_NAV_Name', 'Scheme_Min_Amt', 'NAV', 'Latest_NAV_Date',
#        'Average_AUM_Cr', 'AAUM_Quarter', 'ISIN_Div_Payout/Growth',
#        'ISIN_Div_Reinvestment', 'ISIN_Div_Payout/Growth/Div_Reinvestment',
#        'Launch_Date', 'Closure_Date'],
#       dtype='str')

# %%
fund["AMC"].unique()
# Out:
# <StringArray>
# [                          'Aditya Birla Sun Life AMC Limited',
#                           'DSP Asset Managers Private Limited',
#                        'HDFC Asset Management Company Limited',
#                                 'quant Money Managers Limited',
#                        'JM Financial Asset Management Limited',
#             'Kotak Mahindra Asset Management Company Limited.',
#                     'LIC Mutual Fund Asset Management Limited',
#              'Sahara Asset Management Company Private Limited',
#            'ICICI Prudential Asset Management Company Limited',
#                   'Nippon Life India Asset Management Limited',
#                                'Tata Asset Management Limited',
#  'Franklin Templeton Asset Management (India) Private Limited',
#                      'Taurus Asset Management Company Limited',
#               'Canara Robeco Asset Management Company Limited',
# ...

# %%
fund.dtypes
# Out:
# Scheme_Code                                  int64
# Scheme_Name                                    str
# AMC                                            str
# Scheme_Type                                    str
# Scheme_Category                                str
# Scheme_NAV_Name                                str
# Scheme_Min_Amt                                 str
# NAV                                        float64
# Latest_NAV_Date                                str
# Average_AUM_Cr                             float64
# AAUM_Quarter                                   str
# ISIN_Div_Payout/Growth                         str
# ISIN_Div_Reinvestment                          str
# ISIN_Div_Payout/Growth/Div_Reinvestment        str
# Launch_Date                                    str
# Closure_Date                                   str
# dtype: object

# %%
fund.isnull().sum()
# Out:
# Scheme_Code                                    0
# Scheme_Name                                    0
# AMC                                            0
# Scheme_Type                                    0
# Scheme_Category                                0
# Scheme_NAV_Name                                0
# Scheme_Min_Amt                                30
# NAV                                         2024
# Latest_NAV_Date                             2024
# Average_AUM_Cr                              8049
# AAUM_Quarter                                8049
# ISIN_Div_Payout/Growth                      2024
# ISIN_Div_Reinvestment                       2024
# ISIN_Div_Payout/Growth/Div_Reinvestment     1387
# Launch_Date                                   21
# Closure_Date                               12388
# dtype: int64

# %%
import pandas as pd

fund = pd.read_csv("c:/Users/Divya/Downloads/MutualFundAnalytics_Project_1/data/raw/fund_master.csv")
nav = pd.read_csv("c:/Users/Divya/Downloads/MutualFundAnalytics_Project_1/data/raw/nav_history.csv")

# %%
missing_codes = fund[~fund["Scheme_Code"].isin(nav["Scheme_Code"])]

missing_codes
# Out:
#        Scheme_Code                            Scheme_Name  \
# 4           100039      Aditya Birla Sun Life Income Fund
# 5           100040      Aditya Birla Sun Life Income Fund
# 13          100050      Aditya Birla Sun Life Liquid Fund
# 35          100125                       HDFC Income Fund
# 36          100126                       HDFC Income Fund
# ...            ...                                    ...
# 16238       154437           Zerodha Life Cycle Fund 2041
# 16239       154438  ALPHAGREP MULTI ASSET ALLOCATION FUND
# 16240       154440  ALPHAGREP MULTI ASSET ALLOCATION FUND
# 16241       154442  ALPHAGREP MULTI ASSET ALLOCATION FUND
# 16242       154443  ALPHAGREP MULTI ASSET ALLOCATION FUND
#
#                                                    AMC Scheme_Type  \
# 4                    Aditya Birla Sun Life AMC Limited  Open Ended
# 5                    Aditya Birla Sun Life AMC Limited  Open Ended
# ...

# %%
missing_codes = fund[fund["Scheme_Code"].isin(nav["Scheme_Code"])]

missing_codes
# Out:
#        Scheme_Code                                 Scheme_Name  \
# 0           100033  Aditya Birla Sun Life Large & Mid Cap Fund
# 1           100034  Aditya Birla Sun Life Large & Mid Cap Fund
# 2           100037           Aditya Birla Sun Life Income Fund
# 3           100038           Aditya Birla Sun Life Income Fund
# 6           100041           Aditya Birla Sun Life Liquid Fund
# ...            ...                                         ...
# 16200       154396                      Shriram Overnight Fund
# 16202       154398                      Shriram Overnight Fund
# 16203       154399                      Shriram Overnight Fund
# 16206       154402                      Shriram Overnight Fund
# 16228       154426                            DSP Savings Fund
#
#                                       AMC Scheme_Type  \
# 0       Aditya Birla Sun Life AMC Limited  Open Ended
# 1       Aditya Birla Sun Life AMC Limited  Open Ended
# ...
